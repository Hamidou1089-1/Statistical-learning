# %%
import numpy as np

x = np.random.normal(size=50)

y = x + np.random.normal(loc=50, scale=1, size=50)

np.corrcoef(x,y)
# Out:
# array([[1.    , 0.7827],
#        [0.7827, 1.    ]])

# %%
rng =  np.random.default_rng(3)

y =  rng.standard_normal(10)
np.mean(y), y.mean()
# Out:
# (np.float64(-0.1126795190952861), np.float64(-0.1126795190952861))

# %%
np.var(y), y.var(), np.mean((y - y.mean())**2)
# Out:
# (np.float64(2.7243406406465125),
#  np.float64(2.7243406406465125),
#  np.float64(2.7243406406465125))

# %%
np.sqrt(np.var(y)), np.std(y)
# Out:
# (np.float64(1.6505576756498128), np.float64(1.6505576756498128))

# %%
X = rng.standard_normal((10, 3))
X.mean(axis = 0)
# Out:
# array([ 0.13922331, -0.14649843, -0.46084178])

# %%
X.mean(0)
# Out:
# array([ 0.13922331, -0.14649843, -0.46084178])

# %%
from matplotlib.pyplot import subplots

fig, ax = subplots(figsize=(8,8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.plot(x, y);

# %%
fig, ax = subplots(nrows = 2,
                   ncols=3,
                   figsize=(8, 8))
ax[0,1].set_xlim([-1,1])
# Out:
# (-1.0, 1.0)

# %%
fig.set_size_inches(12,3)
fig

# %%
# Generer 100 point random, avec une distribution normale centrée et reduite
import numpy as np
x = np.array([2,3,32,2])
for k in x:
    np.extract(k == 2,x)
# Out:
# array([ 0.46469894, -0.87518316,  1.49365423,  0.31542987, -2.40294477,
#        -0.16330806,  1.06148626, -0.40382685,  1.6122909 , -0.70484165,
#         1.3854327 ,  0.11086032,  1.61949448, -0.93276918,  0.18565142,
#        -0.0736426 , -0.36664129, -0.01756249,  0.81697086,  0.39015268,
#         1.51261608, -0.47464155,  0.8699084 , -0.6863505 , -0.4036196 ,
#         0.55968268, -0.11106865, -0.99247615, -0.62329404, -0.76479798,
#         0.31870842,  0.1175256 , -0.51936889, -1.27900687, -1.33636017,
#         0.19709782,  1.18794291, -0.18967343, -2.07206335, -0.35109581,
#        -0.38104309,  0.09508303,  0.38181232, -1.25234194,  1.24537787,
#         0.96872831, -0.2624387 , -0.3464917 ,  0.10234225, -0.89942873,
#         1.23685051, -0.41782158, -0.88397499, -0.91942242,  1.4916375 ,
#        -1.15925877,  1.33602135,  0.23087061, -0.66169827, -0.74563938,
#         0.13581825, -1.38063887,  1.70850952,  1.05916361, -1.33823187,
#         0.37603137,  0.51451586,  0.30583956,  1.25381323, -0.78626305,
#        -0.36588758, -0.98745218,  0.4590037 , -0.62492131,  0.46630064,
#        -0.22430806, -1.29369015, -1.06610757, -0.78512576, -1.38502141,
#         1.26581929, -0.90964329,  0.26399285, -2.212686  ,  1.61707367,
#         0.68848284,  0.13754118,  0.60838028, -1.13962937, -0.10782127,
#         0.437232  ,  0.10070803,  0.66747414,  1.64374377,  0.81457549,
#        -0.03509712, -1.19122951,  0.20029245, -2.31976639, -1.38205851])
