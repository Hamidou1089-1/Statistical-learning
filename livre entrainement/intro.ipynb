# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng(100003)

# %%
x = rng.beta(a = 2, b = 7, size = 100)
y = rng.beta(a = 7, b = 2, size = 100)
plt.hist([x,y], 50, density = True, histtype='bar');

# %%
import pandas as pd
Auto = pd.read_csv('Auto.csv',
                   na_values=['?']
                   )
Auto_new = Auto.dropna()
Auto = Auto_new

Auto.cylinders = pd.Series(Auto.cylinders, dtype='category')
pd.plotting.scatter_matrix(Auto[['mpg', 'displacement','weight']]);
Auto['mpg'].describe()
# Out:
# count    392.000000
# mean      23.445918
# std        7.805007
# min        9.000000
# 25%       17.000000
# 50%       22.750000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
print(1)
print(_)
# Out:
# 1

# %%
print(_)
